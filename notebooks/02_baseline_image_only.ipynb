# %% [markdown]
# # Baseline Image-Only Classifier
#
# Training a ResNet18 model on the RVL-CDIP sample dataset for document classification.

# %% [markdown]
# ## Setup and Imports
#
# First, let's add the project root to the path and import the necessary modules.

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from src.training.train_image_classifier import train_model
from src.utils.paths import RAW_DATA_DIR

RAW_DATA_DIR

# %% [markdown]
# ## Define Dataset Path
#
# Point to the saved RVL-CDIP sample directory.

# %%
sample_dir = RAW_DATA_DIR / "rvl_cdip_sample"
sample_dir

# %% [markdown]
# ## Train the Model
#
# Train a ResNet18 image classifier on the sample dataset. This will take a few minutes on CPU.

# %%
train_model(
    sample_dir=sample_dir,
    epochs=3,
    batch_size=8,
    lr=1e-4,
    device="cpu"
)
