# %% [markdown]
# # Baseline Text-Only Classifier
#
# Training a DistilBERT model on OCR-extracted text from the RVL-CDIP sample dataset for document classification.

# %% [markdown]
# ## Setup and Imports
#
# Import the training function and define paths.

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from src.training.train_text_classifier import train_text_model
from src.utils.paths import RAW_DATA_DIR

RAW_DATA_DIR
# Out:
# WindowsPath('C:/Users/usman/ML_Projects/multi_input_ocr/data/raw')

# %% [markdown]
# ## Define Dataset Path
#
# Point to the RVL-CDIP sample directory containing `labels_with_text.csv`.

# %%
sample_dir = RAW_DATA_DIR / "rvl_cdip_sample"
sample_dir
# Out:
# WindowsPath('C:/Users/usman/ML_Projects/multi_input_ocr/data/raw/rvl_cdip_sample')

# %% [markdown]
# ## Train the Text Model
#
# Fine-tune DistilBERT on the OCR-extracted text. This will take several minutes on CPU.

# %%
train_text_model(
    sample_dir=sample_dir,
    epochs=3,
    batch_size=8,
    lr=2e-5,
    max_length=256,
    device="cpu"
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3 - Loss: 2.7560 - Acc: 0.0750
# Epoch 2/3 - Loss: 2.6765 - Acc: 0.1950
# Epoch 2/3 - Loss: 2.6765 - Acc: 0.1950
# Epoch 3/3 - Loss: 2.5931 - Acc: 0.3100
# Epoch 3/3 - Loss: 2.5931 - Acc: 0.3100
# Saved text model checkpoint to: C:\Users\usman\ML_Projects\multi_input_ocr\data\raw\rvl_cdip_sample\distilbert_text_sample.pth
# Saved text model checkpoint to: C:\Users\usman\ML_Projects\multi_input_ocr\data\raw\rvl_cdip_sample\distilbert_text_sample.pth
